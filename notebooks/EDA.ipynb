# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'C:\Users\Lenovo\Documents\GitHub\Aero-Tool-Cast\data\Aero_raw_data.xlsx')

# %%
df
# Out:
#                      FL_DATE OP_UNIQUE_CARRIER TAIL_NUM ORIGIN DEST  \
# 0        2023-01-01 00:00:00                UA      NaN    DFW  IAH
# 1        2023-01-01 00:00:00                UA      NaN    EWR  LAX
# 2        2023-01-01 00:00:00                UA      NaN    FLL  EWR
# 3        2023-01-01 00:00:00                UA      NaN    IAD  FLL
# 4        2023-01-01 00:00:00                UA      NaN    IAD  STT
# ...                      ...               ...      ...    ...  ...
# 56652  1/31/2023 12:00:00 AM                UA   N899UA    CID  DEN
# 56653  1/31/2023 12:00:00 AM                UA   N899UA    DEN  CID
# 56654  1/31/2023 12:00:00 AM                UA   N899UA    ELP  DEN
# 56655  1/31/2023 12:00:00 AM                UA   N91007    HNL  ORD
# 56656  1/31/2023 12:00:00 AM                UA   N91007    ORD  HNL
#
#        CANCELLED  DISTANCE
# 0              1       224
# 1              1      2454
# 2              1      1065
# 3              1       901
# 4              1      1606
# ...          ...       ...
# 56652          0       692
# 56653          0       692
# 56654          0       563
# 56655          0      4243
# 56656          0      4243
#
# [56657 rows x 7 columns]
